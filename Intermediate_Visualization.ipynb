# %% [markdown]
# <a href="https://colab.research.google.com/github/pingkivila/DigitalSkola_DataScience11/blob/main/Intermediate_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Line Chart

# %%
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.pyplot import figure
import numpy as np

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
# Without Line

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
# Marker

plt.plot(xpoints, ypoints, marker = 'o')
plt.show()

# %%
# Dotted Line Chart

plt.plot(xpoints, ypoints, linestyle='dashdot')
plt.show()

# %%
# Axis Label

plt.plot(xpoints, ypoints)

plt.xlabel("sumbu x")
plt.ylabel("sumbu y")

plt.show()

# %%
# Grid

plt.plot(xpoints, ypoints)

plt.xlabel("x axis")
plt.ylabel("y axis")

plt.grid(axis = 'x')

plt.show()

# %% [markdown]
# ## Scatterplot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y, color = 'red')
plt.show()

# %%
# Colored Scatterplot

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#000000')

plt.show()

# %%
# CMap

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='magma')

plt.colorbar()

plt.show()

# %% [markdown]
# ## Bar Chart

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
# Colored Barchart

x = np.array(["D", "B", "A", "C"])
y = np.array([10, 8, 3, 1])

plt.bar(x, y, color = "darkgreen")
plt.show()

# %%
x = np.array(["D", "C", "B", "A"])
y = np.array([1, 3, 8, 10])

plt.barh(x, y)
plt.show()

# %% [markdown]
# ## Histogram

# %%
np.random.seed(192)
x = np.random.normal(200, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Mango"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
# Explode

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0, 0, 0, 0.9]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# ## Box Plot

# %%
np.random.seed(11)
data = np.random.normal(100, 20, 200)

plt.boxplot(data)
  
plt.show()

# %% [markdown]
# ## Area Chart

# %%
x=range(1,6)
y1=[1,4,6,8,9]
y2=[2,2,7,10,12]


plt.stackplot(x, y1, y2, labels=['Data Science','Data Engineer'])
plt.xticks(x)

plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(x, y1)
plt.plot(x, y2)
plt.show()

# %% [markdown]
# ## Axes

# %%
# create some data to use for the plot
dt = 0.001
t = np.arange(0.0, 10.0, dt)
r = np.exp(-t[:1000] / 0.05)  # impulse response
x = np.random.randn(len(t))
s = np.convolve(x, r)[:len(x)] * dt  # colored noise

fig, main_ax = plt.subplots()
main_ax.plot(t, s)
main_ax.set_xlim(0, 1)
main_ax.set_ylim(1.1 * np.min(s), 2 * np.max(s))
main_ax.set_xlabel('time (s)')
main_ax.set_ylabel('current (nA)')
main_ax.set_title('Gaussian colored noise')

# this is an inset axes over the main axes
right_inset_ax = fig.add_axes([.65, .6, .2, .2], facecolor='k') #  [left, bottom, width, height]
right_inset_ax.hist(s, 400, density=True)
right_inset_ax.set(title='Probability', xticks=[], yticks=[])

# this is another inset axes over the main axes
left_inset_ax = fig.add_axes([.2, .6, .2, .2], facecolor='k') #  [left, bottom, width, height]
left_inset_ax.plot(t[:len(r)], r)
left_inset_ax.set(title='Impulse response', xlim=(0, .2), xticks=[], yticks=[])

plt.show()

# %% [markdown]
# ## Subplot

# %% [markdown]
# ### 1st way

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 3, 2])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ### 2nd way

# %%
# Initialize the plot
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

# or replace the three lines of code above by the following line: 
#fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,10))

# Plot the data
ax1.bar([1,2,3],[3,4,5])
ax2.barh([0.5,1,2.5],[0,1,2])

# Show the plot
plt.show()

# %% [markdown]
# ## Legend

# %%
fig, ax = plt.subplots()
line_up, = ax.plot([1, 2, 3], label='Line 2')
line_down, = ax.plot([3, 2, 1], label='Line 1')
ax.legend([line_up, line_down], ['Line Up', 'Line Down'])

# %% [markdown]
# ## Annotation

# %%
fig, ax = plt.subplots()
 
t = np.arange(0.0, 1.0, 0.001)
s = np.sin(2 * np.pi * t)
line = ax.plot(t, s, lw=2)
 
ax.annotate('Peak Value', xy=(.25, 1),
                xytext=(1, 1),arrowprops=dict(facecolor='red',
                                shrink=0.05),xycoords="data",)
 
ax.set_ylim(-2, 2)
plt.show()

# %%
fig, ax = plt.subplots()

x = np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.axis('equal')

ax.annotate('local maximum', xy=(6.28, 1), xytext=(10, 4),
            arrowprops=dict(facecolor='black', shrink=0.05))

ax.annotate('local minimum', xy=(5 * np.pi, -1), xytext=(2, -6),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="angle3,angleA=0,angleB=-90"));

# %%
y = [3.2, 3.9, 3.7, 3.5, 3.02199]
x = [0.15, 0.3, 0.45, 0.6, 0.75]
n = [155, "outlier", 293, 230, 670]
 
fig, ax = plt.subplots()
ax.scatter(x, y)
 
for i, txt in enumerate(n):
    ax.annotate(txt, (x[i], y[i]))
plt.show()

# %%
labels = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']
shop_a = [20, 33, 30, 28, 27]
shop_b = [25, 32, 33, 20, 25]
 
x = np.arange(len(labels))  
width = 0.35  # the width of the bars
 
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, shop_a, width, label='Sales-a')
rects2 = ax.bar(x + width/2, shop_b, width, label='sales-b')
 
 
ax.set_ylabel('Sales')
ax.set_title('Sales report of 2 shops')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
 
 
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  
                    textcoords="offset points", size=16,color="Green",
                    ha='center', va='bottom')
 
 
autolabel(rects1)
autolabel(rects2)
 
fig.tight_layout()
 
plt.show()
plt.savefig('test.png')

# %%
"/content/drive/MyDrive/test.png"

# %%
from google.colab import drive
drive.mount('/content/drive')
