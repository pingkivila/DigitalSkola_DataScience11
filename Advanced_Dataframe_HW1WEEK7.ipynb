# %% [markdown]
# <a href="https://colab.research.google.com/github/pingkivila/DigitalSkola/blob/main/Advanced_Dataframe_HW1WEEK7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Advanced Dataframe**
#
# This notebook is created to teach student about dataframe advanced level. All the code is free to reuse by everyone.
#
# **Contents**
# 1. Indexing Dataframe
# 2. Dropping Variable/Column
# 3. Joining Dataframe
# 4. Concatenate & Append Dataframe
# 5. Pivot Table Dataframe
# 6. Melting Dataframe
# 7. Fungsi Lambda dalam Dataframe
#
# ___

# %%
#import library
import pandas as pd
import numpy as np

import plotly.express as px
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/densaiko/data_science_learning/main/dataset/insurance.csv")
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ### Indexing Dataframe

# %%
random_ = data.sample(n=10)
random_.head()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 741    27    male  29.15         0    yes  southeast  18246.4955
# 811    33  female  42.94         3     no  northwest   6360.9936
# 1038   22    male  28.88         0     no  northeast   2250.8352
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 615    47  female  36.63         1    yes  southeast  42969.8527

# %%
## reset index starting from 0
random_.reset_index(drop=True)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   27    male  29.150         0    yes  southeast  18246.49550
# 1   33  female  42.940         3     no  northwest   6360.99360
# 2   22    male  28.880         0     no  northeast   2250.83520
# 3   21  female  25.800         0     no  southwest   2007.94500
# 4   47  female  36.630         1    yes  southeast  42969.85270
# 5   29  female  31.160         0     no  northeast   3943.59540
# 6   18    male  28.310         1     no  northeast  11272.33139
# 7   44    male  39.520         0     no  northwest   6948.70080
# 8   55    male  29.900         0     no  southwest  10214.63600
# 9   59  female  26.505         0     no  northeast  12815.44495

# %%
## set column as index
random_.set_index('age')
# Out:
#         sex     bmi  children smoker     region      charges
# age
# 27     male  29.150         0    yes  southeast  18246.49550
# 33   female  42.940         3     no  northwest   6360.99360
# 22     male  28.880         0     no  northeast   2250.83520
# 21   female  25.800         0     no  southwest   2007.94500
# 47   female  36.630         1    yes  southeast  42969.85270
# 29   female  31.160         0     no  northeast   3943.59540
# 18     male  28.310         1     no  northeast  11272.33139
# 44     male  39.520         0     no  northwest   6948.70080
# 55     male  29.900         0     no  southwest  10214.63600
# 59   female  26.505         0     no  northeast  12815.44495

# %% [markdown]
# ### Dropping Variable/Column

# %%
# dropping column
data.drop(['bmi','children'], axis=1).head()
# Out:
#    age     sex smoker     region      charges
# 0   19  female    yes  southwest  16884.92400
# 1   18    male     no  southeast   1725.55230
# 2   28    male     no  southeast   4449.46200
# 3   33    male     no  northwest  21984.47061
# 4   32    male     no  northwest   3866.85520

# %% [markdown]
# ### Joining Dataframe

# %%
data_dummy = data.iloc[:3,0:2]
data_dummy
# Out:
#    age     sex
# 0   19  female
# 1   18    male
# 2   28    male

# %%
data_5 = data.loc[:4,["age","bmi"]]
data_5
# Out:
#    age     bmi
# 0   19  27.900
# 1   18  33.770
# 2   28  33.000
# 3   33  22.705
# 4   32  28.880

# %%
data_5.join(data_dummy, lsuffix='_first', rsuffix='_second')
# Out:
#    age_first     bmi  age_second     sex
# 0         19  27.900        19.0  female
# 1         18  33.770        18.0    male
# 2         28  33.000        28.0    male
# 3         33  22.705         NaN     NaN
# 4         32  28.880         NaN     NaN

# %% [markdown]
# ### Concatenate & Append Dataframe

# %%
# concatenate data in horizontal
pd.concat([data_dummy,data_5], axis=1)
# Out:
#     age     sex  age     bmi
# 0  19.0  female   19  27.900
# 1  18.0    male   18  33.770
# 2  28.0    male   28  33.000
# 3   NaN     NaN   33  22.705
# 4   NaN     NaN   32  28.880

# %%
# concatenate data in vertical
pd.concat([data_dummy,data_5], axis=0)
# Out:
#    age     sex     bmi
# 0   19  female     NaN
# 1   18    male     NaN
# 2   28    male     NaN
# 0   19     NaN  27.900
# 1   18     NaN  33.770
# 2   28     NaN  33.000
# 3   33     NaN  22.705
# 4   32     NaN  28.880

# %%
# append data
data_5.append(data_dummy)
# Out:
#    age     bmi     sex
# 0   19  27.900     NaN
# 1   18  33.770     NaN
# 2   28  33.000     NaN
# 3   33  22.705     NaN
# 4   32  28.880     NaN
# 0   19     NaN  female
# 1   18     NaN    male
# 2   28     NaN    male

# %% [markdown]
# ### Pivot Table Dataframe

# %%
# pivot table
pd.pivot_table(data, values="bmi", index=["sex","smoker"], columns="region", 
               aggfunc=np.sum)
# Out:
# region         northeast  northwest  southeast  southwest
# sex    smoker
# female no       3930.625   3980.975    4556.42     4237.1
#        yes       790.590    820.610    1161.05      632.7
# male   no       3607.720   3818.810    4573.36     3908.5
#        yes      1123.280    869.535    1850.75     1165.6

# %%
# pivot table
pd.pivot_table(data, values="bmi", index=["sex","smoker"], columns="region", 
               aggfunc=np.max)
# Out:
# region         northeast  northwest  southeast  southwest
# sex    smoker
# female no         48.070     42.940      46.75       46.7
#        yes        42.750     38.950      47.41       47.6
# male   no         42.655     41.325      53.13       45.9
#        yes        41.895     40.565      52.58       39.9

# %% [markdown]
# ### Melting Dataframe

# %%
data_melt = data.iloc[:5,:3]
data_melt
# Out:
#    age     sex     bmi
# 0   19  female  27.900
# 1   18    male  33.770
# 2   28    male  33.000
# 3   33    male  22.705
# 4   32    male  28.880

# %%
pd.melt(data_melt, id_vars=["sex"], value_vars=["age"])
# Out:
#       sex variable  value
# 0  female      age     19
# 1    male      age     18
# 2    male      age     28
# 3    male      age     33
# 4    male      age     32

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
female = data[data["sex"] == "female"]
male = data[data['sex'] == "male"]

# %%
#Summing the region in each sex
female_se=(female['region']=='southeast').sum()
female_sw=(female['region']=='southwest').sum()
female_nw=(female['region']=='northwest').sum()
female_ne=(female['region']=='northeast').sum()

#Summing the region in each sex
male_se=(male['region']=='southeast').sum()
male_sw=(male['region']=='southwest').sum()
male_nw=(male['region']=='northwest').sum()
male_ne=(male['region']=='northeast').sum()

# %%
dict_data = [{'Sex':"Male", "southeast":male_se, "southwest":male_sw,\
              "northwest":male_nw, "northeast":male_ne},
             {'Sex':"Female", "southeast":female_se, "southwest":female_sw,\
              "northwest":female_nw, "northeast":female_ne}]

data_sex = pd.DataFrame(dict_data)
data_sex
# Out:
#       Sex  southeast  southwest  northwest  northeast
# 0    Male        189        163        161        163
# 1  Female        175        162        164        161

# %%
data_sex_melt = data_sex.melt(id_vars="Sex", value_vars=['southeast','southwest','northwest','northeast'])
data_sex_melt
# Out:
#       Sex   variable  value
# 0    Male  southeast    189
# 1  Female  southeast    175
# 2    Male  southwest    163
# 3  Female  southwest    162
# 4    Male  northwest    161
# 5  Female  northwest    164
# 6    Male  northeast    163
# 7  Female  northeast    161

# %%
data_sex_m = data_sex_melt[data_sex_melt["Sex"] == "Male"]

#color palette
ylw = '#fcd12a' # cases - yellow
dth = '#ff2e63' # death - red
rec = '#21bf73' # recovered - cyan

fig=px.treemap(data_sex_m, path=['variable'], values='value', height=500, width=800, color_discrete_sequence=[ylw, dth, rec])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ebf7211a-8fca-4f35-9ac2-a0bb399b49a7" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ebf7211a-8fca-4f35-9ac2-a0bb399b49a7")) {                    Plotly.newPlot(                        "ebf7211a-8fca-4f35-9ac2-a0bb399b49a7",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>value=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["northeast","northwest","southeast","southwest"],"labels":["northeast","northwest","southeast","southwest"],"name":"","parents":["","","",""],"values":[163,161,189,163],"type":"treemap"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line": ...

# %%
data_sex_f = data_sex_melt[data_sex_melt["Sex"] == "Female"]

#color palette
ylw = '#fcd12a' # cases - yellow
dth = '#ff2e63' # death - red
rec = '#21bf73' # recovered - cyan

fig=px.treemap(data_sex_f, path=['variable'], values='value', height=500, width=800, color_discrete_sequence=[ylw, dth, rec])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2224fb88-b624-4983-a3f8-16f18858a330" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2224fb88-b624-4983-a3f8-16f18858a330")) {                    Plotly.newPlot(                        "2224fb88-b624-4983-a3f8-16f18858a330",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>value=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["northeast","northwest","southeast","southwest"],"labels":["northeast","northwest","southeast","southwest"],"name":"","parents":["","","",""],"values":[161,164,175,162],"type":"treemap"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line": ...

# %% [markdown]
# ### Fungsi Lambda dalam Dataframe

# %%
# basic lambda
test = lambda a: a*3
test(10)
# Out:
# 30

# %%
# create new variables/columns
curila = []

for i in data['bmi']:
  if i < 26:
    curila.append("Low BMI")
  else:
    curila.append("High BMI")

data_lambda = data.copy()
data_lambda['bmi_category'] = curila
data_lambda.head()
# Out:
#    age     sex     bmi  children smoker     region      charges bmi_category
# 0   19  female  27.900         0    yes  southwest  16884.92400     High BMI
# 1   18    male  33.770         1     no  southeast   1725.55230     High BMI
# 2   28    male  33.000         3     no  southeast   4449.46200     High BMI
# 3   33    male  22.705         0     no  northwest  21984.47061      Low BMI
# 4   32    male  28.880         0     no  northwest   3866.85520     High BMI

# %%
plt.hist(data['age'])
# Out:
# (array([222., 140., 109., 128., 102., 137., 144., 114., 128., 114.]),
#  array([18. , 22.6, 27.2, 31.8, 36.4, 41. , 45.6, 50.2, 54.8, 59.4, 64. ]),
#  <a list of 10 Patch objects>)

# %%
# create new variables/columns with lambda
data["bmi_categ_lambda"] = data['bmi'].apply(lambda x: "High BMI" if x>=50 and x<=60 else "Medium BMI" if x>=30 and x<50  else "Low BMI")
data.head()
# Out:
#    age     sex     bmi  ...     region      charges bmi_categ_lambda
# 0   19  female  27.900  ...  southwest  16884.92400          Low BMI
# 1   18    male  33.770  ...  southeast   1725.55230       Medium BMI
# 2   28    male  33.000  ...  southeast   4449.46200       Medium BMI
# 3   33    male  22.705  ...  northwest  21984.47061          Low BMI
# 4   32    male  28.880  ...  northwest   3866.85520          Low BMI
#
# [5 rows x 8 columns]

# %% [markdown]
# ## Homework

# %%
pd.pivot_table(data, values=["bmi"], index=['bmi_categ_lambda'], aggfunc={'bmi':[min, max, np.mean]})
# Out:
#                      bmi
#                      max       mean    min
# bmi_categ_lambda
# High BMI          53.130  52.030000  50.38
# Low BMI           29.925  25.506426  15.96
# Medium BMI        49.060  35.194574  30.00

# %%
# set the bmi_categ_lambda, sex, and region in upper char
data[['sex',"region","bmi_categ_lambda"]] = data.apply(lambda x: x[['sex',"region","bmi_categ_lambda"]].str.upper(), axis = 1)
data.head()
# Out:
#    age     sex     bmi  ...     region      charges bmi_categ_lambda
# 0   19  FEMALE  27.900  ...  SOUTHWEST  16884.92400          LOW BMI
# 1   18    MALE  33.770  ...  SOUTHEAST   1725.55230       MEDIUM BMI
# 2   28    MALE  33.000  ...  SOUTHEAST   4449.46200       MEDIUM BMI
# 3   33    MALE  22.705  ...  NORTHWEST  21984.47061          LOW BMI
# 4   32    MALE  28.880  ...  NORTHWEST   3866.85520          LOW BMI
#
# [5 rows x 8 columns]
